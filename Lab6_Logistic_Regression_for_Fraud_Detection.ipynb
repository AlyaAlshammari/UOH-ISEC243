# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyaAlshammari/UOH-ISEC243/blob/main/Lab6_Logistic_Regression_for_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML Applications in Security

# %% [markdown]
# Machine Learning is employed in various security applications such as:

# %% [markdown]
# *   Logistic Regression for Fraud Detection.
# *   Spam Fighting using Naive Bayes.
# *   Support Vector Machines and Malware Detection

# %% [markdown]
# In this notebook, we explore fraud detection using Logistic Regression.

# %% [markdown]
# **Library:** sklearn
#
# **Dataset:** payment_fraud

# %% [markdown]
# The source of this notbook is https://github.com/oreilly-mlsec/book-resources/blob/master/chapter2/logistic-regression-fraud-detection.ipynb

# %% [markdown]
# Import the libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Upload the dataset file to Colab first:
#
#
# 1.   Go to files.
# 2.   Click upload to session Storage.

# %%
# Read in the data from the CSV file
df = pd.read_csv('/content/payment_fraud.csv')

# %%
# Explore the data

df.sample(30)
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 28432             790         1   4.876771    creditcard
# 26049              79         1   5.017904    creditcard
# 19148             895         1   4.895263    creditcard
# 2051             2000         1   4.921349        paypal
# 21208            1157         1   4.742303    creditcard
# 11292               7         1   4.965339        paypal
# 13576             209         1   5.034622        paypal
# 21985               2         1   5.034622    creditcard
# 2362             2000         1   3.575983        paypal
# 9529              173         1   4.876771    creditcard
# 4728             2000         3   4.886641    creditcard
# 21591              94         1   4.461622    creditcard
# 30410            1111         1   4.921318        paypal
# 19019             140         1   4.505662        paypal
# 18122             877         1   4.748314    creditcard
# ...

# %%
# Convert categorical feature into dummy variables with one-hot encoding
df = pd.get_dummies(df, columns=['paymentMethod'])
df.sample(3)
# Out:
#        accountAgeDays  numItems  localTime  paymentMethodAgeDays  label  \
# 12598             402         1   4.895263              0.000000      0
# 26340            2000         1   5.017904              0.000694      0
# 13559            2000         1   4.921349              0.953472      0
#
#        paymentMethod_creditcard  paymentMethod_paypal  \
# 12598                     False                 False
# 26340                     False                  True
# 13559                      True                 False
#
#        paymentMethod_storecredit
# 12598                       True
# 26340                      False
# 13559                      False

# %%
# Split dataset up into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('label', axis=1), df['label'],
    test_size=0.33, random_state=17)

# %%
# Initialize and train classifier model
clf = LogisticRegression().fit(X_train, y_train)

# %%
# Make predictions on test set
y_pred = clf.predict(X_test)

# %%
# Compare test set predictions with ground truth labels
print(accuracy_score(y_pred, y_test))
print(confusion_matrix(y_test, y_pred))
# Out:
# 1.0
# [[12753     0]
#  [    0   190]]
